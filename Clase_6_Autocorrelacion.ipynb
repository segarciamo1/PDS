# %% [markdown]
# # Clase 6: Autocorrelacion

# %%
import matplotlib.pyplot as plt # libreria usada para graficas
import numpy as np

# %%
rect_pulse=np.ones(20)
ti=np.arange(0,20,1)

plt.figure(figsize=(10,5))
plt.stem(ti,rect_pulse)
plt.title("Pulso de 20 muestras",size=18)
plt.grid()

# %%
Rxx=np.correlate(rect_pulse, rect_pulse, mode='full')
tau=np.arange(-len(rect_pulse)+1,len(rect_pulse),1) # vector de retraso

plt.figure(figsize=(10,5))
plt.plot(tau,Rxx) # Dibujar la grafica
plt.title("Función de autocorrelación del pulso de 20 muestras",size=18)
plt.xlabel('Desplazamiento (n)', fontsize=18)
plt.ylabel('Amplitud',fontsize=18)
plt.grid()
